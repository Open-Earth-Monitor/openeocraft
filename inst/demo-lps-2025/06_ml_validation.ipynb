# %% [markdown]
# # ML Model Validation
#
# This notebook demonstrates model validation using `ml_validate_kfold`, which:
#
# 1. Runs **k-fold cross-validation** on an untrained model specification
# 2. Writes structured metrics to **`metrics.json`** (overall scores, per-class F1/precision/recall, confusion matrix)
# 3. **Refits the model on the full training set** and returns a trained `ml-model` ready for `ml_predict()` or `save_ml_model()`
#
# We use Random Forest because it is fast and well suited to satellite time-series classification demos.

# %%
import json
from pathlib import Path

import openeo  # type: ignore

# %%
connection = openeo.connect(url="http://127.0.0.1:8000")
connection.authenticate_basic("brian", "123456")
# Out:
# <Connection to 'http://127.0.0.1:8000/' with BasicBearerAuth>

# %%
training_set = (
    "https://github.com/e-sensing/sitsdata/raw/main/data/"
    "samples_deforestation_rondonia.rds"
)

# %% [markdown]
# ## K-fold cross-validation
#
# The `scoring` argument selects which metrics appear in `metrics.json`:
#
# - **Overall**: `accuracy`, `kappa`, and related confidence statistics
# - **Per class**: `f1`, `precision`, `recall`, `sensitivity`, `specificity`
# - **Confusion matrix**: always included when the task is classification
#
# Pass `scoring` as a single string or a list, e.g. `["accuracy", "kappa", "f1"]`.

# %%
process_graph_kfold = {
    "rf1": {
        "process_id": "mlm_class_random_forest",
        "arguments": {
            "num_trees": 100,
            "seed": 42,
        },
    },
    "validate1": {
        "process_id": "ml_validate_kfold",
        "arguments": {
            "model": {"from_node": "rf1"},
            "training_data": training_set,
            "folds": 5,
            "target": "label",
            "scoring": [
                "accuracy",
                "kappa",
                "f1",
                "precision",
                "recall",
            ],
            "seed": 42,
        },
        "result": True,
    },
}

job_kfold = connection.create_job(
    process_graph=process_graph_kfold,
    title="Random Forest validation (5-fold CV)",
    description="K-fold validation with accuracy, kappa, F1, and confusion matrix",
)
job_kfold.start_and_wait()
results_kfold = job_kfold.get_results()
# Out:
# 0:00:00 Job '8e0c3614b9d9cf35a024950c4172b7a2': send 'start'
# 0:00:01 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:00:06 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:00:13 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:00:21 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:00:30 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:00:43 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:00:58 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:01:17 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:01:41 Job '8e0c3614b9d9cf35a024950c4172b7a2': running (progress N/A)
# 0:02:11 Job '8e0c3614b9d9cf35a024950c4172b7a2': finished (progress N/A)

# %%
output_dir = Path("data/outputs_validation_kfold")
results_kfold.download_files(output_dir)
# Out:
# [PosixPath('data/outputs_validation_kfold/metrics'),
#  PosixPath('data/outputs_validation_kfold/job-results.json')]

# %% [markdown]
# ## View validation metrics
#
# Load `metrics.json` from the job assets and inspect overall scores, per-class metrics, and the confusion matrix.
#
# For a **paper figure**, prefer a **row-normalized** matrix (each row sums to 100%): rows are **true class**, columns are **predicted class**. That highlights recall per class and is easier to read when classes are imbalanced. Export as PDF/SVG at 300 dpi for the manuscript.

# %%
metrics_file = output_dir / "metrics"
if not metrics_file.exists():
    raise FileNotFoundError(f"Metrics asset not found: {metrics_file}")

with open(metrics_file) as f:
    metrics = json.load(f)

print(f"Method: {metrics.get('method')}  |  Folds: {metrics.get('folds')}")
print(f"Scoring requested: {metrics.get('scoring')}")
print("\nOverall metrics:")
print(json.dumps(metrics.get("overall", {}), indent=2))
# Out:
# Method: kfold  |  Folds: 5
# Scoring requested: ['accuracy', 'kappa', 'f1', 'precision', 'recall']
#
# Overall metrics:
# {
#   "accuracy": 0.8914599633760613,
#   "kappa": 0.8721160418326684
# }

# %%
try:
    import pandas as pd

    by_class = metrics.get("by_class", [])
    if by_class:
        df = pd.DataFrame(by_class).set_index("class")
        display(df.round(4))
    else:
        print("No per-class metrics in metrics.json (add f1/precision/recall to scoring).")
except ImportError:
    print(json.dumps(metrics.get("by_class", []), indent=2))
# Out:
#                            f1  precision  recall
# class
# Clear_Cut_Bare_Soil    0.8864     0.8649  0.9089
# Forest                 0.9018     0.8598  0.9481
# Clear_Cut_Burned_Area  0.9081     0.9325  0.8850
# Clear_Cut_Vegetation   0.8239     0.8636  0.7877
# Wetland                0.7926     0.9255  0.6930
# Mountainside_Forest    0.8525     0.9815  0.7536
# Water                  0.9498     0.9455  0.9541
# Seasonally_Flooded     0.8670     0.8736  0.8605
# Riparian_Forest        0.9341     0.9096  0.9599

# %%
def plot_confusion_matrix_for_paper(
    cm_dict,
    *,
    title="Confusion matrix (5-fold CV)",
    save_dir=None,
    dpi=300,
):
    """Publication-style confusion matrix: counts + row-normalized (% of true class)."""
    import matplotlib.pyplot as plt
    import numpy as np

    # Backend stores rows = predicted, cols = reference (caret convention).
    # Papers usually show rows = true class, cols = predicted class -> transpose.
    raw = np.array(cm_dict["matrix"], dtype=float).T
    labels = [name.replace("_", " ") for name in cm_dict["labels"]]

    row_sums = raw.sum(axis=1, keepdims=True)
    norm = np.divide(raw, row_sums, where=row_sums > 0) * 100

    fig, axes = plt.subplots(1, 2, figsize=(12, 5), dpi=dpi)
    cmap_counts = "Blues"
    cmap_norm = "YlGnBu"

    count_annot = np.array([[f"{int(v)}" for v in row] for row in raw])
    norm_annot = np.array(
        [[f"{norm[i, j]:.0f}%\n({int(raw[i, j])})" for j in range(raw.shape[1])]
         for i in range(raw.shape[0])]
    )

    for ax, data, annot, cmap, subtitle in (
        (axes[0], raw, count_annot, cmap_counts, "Counts"),
        (axes[1], norm, norm_annot, cmap_norm, "Row-normalized (% of true class)"),
    ):
        im = ax.imshow(data, cmap=cmap, aspect="auto")
        ax.set_xticks(range(len(labels)))
        ax.set_yticks(range(len(labels)))
        ax.set_xticklabels(labels, rotation=45, ha="right", fontsize=8)
        ax.set_yticklabels(labels, fontsize=8)
        ax.set_xlabel("Predicted class")
        ax.set_ylabel("True class")
        ax.set_title(subtitle, fontsize=10)
        for i in range(data.shape[0]):
            for j in range(data.shape[1]):
                color = "white" if data[i, j] > (0.55 * data.max()) else "black"
                ax.text(j, i, annot[i, j], ha="center", va="center", color=color, fontsize=7)
        fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

    accuracy = metrics.get("overall", {}).get("accuracy")
    kappa = metrics.get("overall", {}).get("kappa")
    subtitle = title
    if accuracy is not None and kappa is not None:
        subtitle += f"\nAccuracy = {accuracy:.3f}, Cohen's κ = {kappa:.3f}"
    fig.suptitle(subtitle, fontsize=11, y=1.02)
    fig.tight_layout()

    if save_dir is not None:
        save_dir = Path(save_dir)
        save_dir.mkdir(parents=True, exist_ok=True)
        for ext in ("pdf", "png"):
            path = save_dir / f"confusion_matrix.{ext}"
            fig.savefig(path, bbox_inches="tight", dpi=dpi)
            print(f"Saved {path}")

    return fig


import matplotlib.pyplot as plt

cm = metrics.get("confusion_matrix")
if cm is None:
    print("No confusion matrix in metrics.json.")
else:
    fig = plot_confusion_matrix_for_paper(
        cm,
        title="Random Forest — Rondônia (aggregated 5-fold CV)",
        save_dir=output_dir / "figures",
    )
    plt.show()
# Out:
# Saved data/outputs_validation_kfold/figures/confusion_matrix.pdf
# Saved data/outputs_validation_kfold/figures/confusion_matrix.png

# %% [markdown]
# ## Save the validated model
#
# `ml_validate_kfold` returns a **trained model** (refit on all samples). Chain `save_ml_model` in the same job to persist it with validation metadata attached.

# %%
process_graph_save = {
    "rf1": {
        "process_id": "mlm_class_random_forest",
        "arguments": {
            "num_trees": 100,
            "seed": 42,
        },
    },
    "validate1": {
        "process_id": "ml_validate_kfold",
        "arguments": {
            "model": {"from_node": "rf1"},
            "training_data": training_set,
            "folds": 5,
            "target": "label",
            "scoring": ["accuracy", "kappa", "f1"],
            "seed": 42,
        },
    },
    "save1": {
        "process_id": "save_ml_model",
        "arguments": {
            "data": {"from_node": "validate1"},
            "name": "rf-validated-kfold",
        },
        "result": True,
    },
}

job_save = connection.create_job(
    process_graph=process_graph_save,
    title="Validate RF and save model",
    description="K-fold validation then save_ml_model",
)
job_save.start_and_wait()
print("Saved model: rf-validated-kfold")
# Out:
# 0:00:00 Job '1030ce178f802abbe4ada590dfb01fb9': send 'start'
# 0:00:02 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:00:07 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:00:13 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:00:21 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:00:31 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:00:43 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:00:58 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:01:17 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:01:41 Job '1030ce178f802abbe4ada590dfb01fb9': running (progress N/A)
# 0:02:11 Job '1030ce178f802abbe4ada590dfb01fb9': finished (progress N/A)
# Saved model: rf-validated-kfold

# %% [markdown]
# ## Related: hold-out validation on a trained model
#
# For evaluating a **trained** model on an independent validation sample set, use `ml_validate` — see [`08_ml_validate.ipynb`](08_ml_validate.ipynb).
#
# `ml_validate_kfold` (this notebook) cross-validates an **untrained** model spec and refits on the full training set. `ml_validate` scores a model already produced by `ml_fit()` (or tuning) without retraining.
